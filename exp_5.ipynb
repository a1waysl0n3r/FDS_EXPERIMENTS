# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\latai\Downloads\nba - nba.csv")
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['first_name'] = df['Name'].str.split().str[0]
df['last_name'] = df['Name'].str.split().str[1]
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary first_name last_name
# ...

# %%
df = df[['Name', 'first_name', 'last_name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']]

# %%
df
# Out:
#               Name first_name last_name            Team  Number Position  Age  \
# 0    Avery Bradley      Avery   Bradley  Boston Celtics       0       PG   25
# 1      Jae Crowder        Jae   Crowder  Boston Celtics      99       SF   25
# 2     John Holland       John   Holland  Boston Celtics      30       SG   27
# 3      R.J. Hunter       R.J.    Hunter  Boston Celtics      28       SG   22
# 4    Jonas Jerebko      Jonas   Jerebko  Boston Celtics       8       PF   29
# ..             ...        ...       ...             ...     ...      ...  ...
# 452     Trey Lyles       Trey     Lyles       Utah Jazz      41       PF   20
# 453   Shelvin Mack    Shelvin      Mack       Utah Jazz       8       PG   26
# 454      Raul Neto       Raul      Neto       Utah Jazz      25       PG   24
# 455   Tibor Pleiss      Tibor    Pleiss       Utah Jazz      21        C   26
# 456    Jeff Withey       Jeff    Withey       Utah Jazz      24        C   26
#
# ...

# %%
df = df.drop(columns = 'Name')

# %%
df
# Out:
#     first_name last_name            Team  Number Position  Age Height  Weight  \
# 0        Avery   Bradley  Boston Celtics       0       PG   25    6-2     180
# 1          Jae   Crowder  Boston Celtics      99       SF   25    6-6     235
# 2         John   Holland  Boston Celtics      30       SG   27    6-5     205
# 3         R.J.    Hunter  Boston Celtics      28       SG   22    6-5     185
# 4        Jonas   Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..         ...       ...             ...     ...      ...  ...    ...     ...
# 452       Trey     Lyles       Utah Jazz      41       PF   20   6-10     234
# 453    Shelvin      Mack       Utah Jazz       8       PG   26    6-3     203
# 454       Raul      Neto       Utah Jazz      25       PG   24    6-1     179
# 455      Tibor    Pleiss       Utah Jazz      21        C   26    7-3     256
# 456       Jeff    Withey       Utah Jazz      24        C   26    7-0     231
#
# ...

# %%
df['Lower_first_name'] = df['first_name'].str.lower()
df
# Out:
#     first_name last_name            Team  Number Position  Age Height  Weight  \
# 0        Avery   Bradley  Boston Celtics       0       PG   25    6-2     180
# 1          Jae   Crowder  Boston Celtics      99       SF   25    6-6     235
# 2         John   Holland  Boston Celtics      30       SG   27    6-5     205
# 3         R.J.    Hunter  Boston Celtics      28       SG   22    6-5     185
# 4        Jonas   Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..         ...       ...             ...     ...      ...  ...    ...     ...
# 452       Trey     Lyles       Utah Jazz      41       PF   20   6-10     234
# 453    Shelvin      Mack       Utah Jazz       8       PG   26    6-3     203
# 454       Raul      Neto       Utah Jazz      25       PG   24    6-1     179
# 455      Tibor    Pleiss       Utah Jazz      21        C   26    7-3     256
# 456       Jeff    Withey       Utah Jazz      24        C   26    7-0     231
#
# ...

# %%
df['Lower_first_name'].str.contains('jae')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# Name: Lower_first_name, Length: 457, dtype: bool

# %%
df.dtypes
# Out:
# first_name           object
# last_name            object
# Team                 object
# Number                int64
# Position             object
# Age                   int64
# Height               object
# Weight                int64
# College              object
# Salary              float64
# Lower_first_name     object
# dtype: object

# %%
df.dtypes
# Out:
# first_name           object
# last_name            object
# Team                 object
# Number                int64
# Position             object
# Age                   int64
# Height               object
# Weight                int64
# College              object
# Salary              float64
# Lower_first_name     object
# dtype: object

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# first_name          0
# last_name           0
# Team                0
# Number              0
# Position            0
# Age                 0
# Height              0
# Weight              0
# College             0
# Salary              0
# Lower_first_name    0
# dtype: int64

# %%
# Out:
# C:\Users\latai\AppData\Local\Temp\ipykernel_7688\843298480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Trim_Team'] = df['Team'].str.strip()
#     first_name last_name            Team  Number Position  Age Height  Weight  \
# 0        Avery   Bradley  Boston Celtics       0       PG   25    6-2     180
# 1          Jae   Crowder  Boston Celtics      99       SF   25    6-6     235
# 3         R.J.    Hunter  Boston Celtics      28       SG   22    6-5     185
# 6       Jordan    Mickey  Boston Celtics      55       PF   21    6-8     235
# 7        Kelly    Olynyk  Boston Celtics      41        C   25    7-0     238
# ..         ...       ...             ...     ...      ...  ...    ...     ...
# ...
