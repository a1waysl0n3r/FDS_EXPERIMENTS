# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\latai\Downloads\diamonds - diamonds.csv")

# %%
df = pd.DataFrame(df)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.groupby('cut').sum()
# Out:
#            Unnamed: 0     carat  \
# cut
# Fair         38877246   1684.28
# Good        121545813   4166.10
# Ideal       626005490  15146.84
# Premium     353052483  12300.95
# Very Good   315307738   9742.70
#
#                                                        color  \
# cut
# Fair       EEFFFHHHGEJGEGIEFGFJIJJFEHHHGFGHDJJHEIGIHGDFFE...
# Good       EJJJJIFEHDDHHIHEEFHEIGFFEEDGFEGEFEIFFGGFGEHIID...
# Ideal      EJJIIIJGIIIDDGIEIEGGIGIFEFEFFGEFDEHDHGDEIDFDGF...
# Premium    EIFEEIFEDJDIGEHHGHHHIHEGGIFFHEFGGDDGGGGDEFEEEE...
# Very Good  JIHHJEHJJGJDFFFEEDDHEHFIIGDHFEDDEEDEGEDGFDDEHF...
#
#                                                      clarity      depth  \
# cut
# Fair       VS2SI2SI2VS2VS2SI2SI2SI2SI1I1SI2VVS1SI2VS1SI1V...   103107.1
# Good       VS1SI2SI1SI1SI1SI2VS1VS1SI1VS2VS1SI2SI2SI1SI1V...   305967.0
# Ideal      SI2VS1SI2SI2SI2SI2SI1VS1SI1SI2VS1SI1SI1VVS2VVS...  1329899.3
# Premium    SI1VS2SI1SI2I1VS1SI1VS2VS2SI2SI1SI2SI1VVS1SI1S...   844901.1
# ...

# %%
df.groupby(['color','cut']).agg('max')
# Out:
#                  Unnamed: 0  carat clarity  depth  table  price      x      y  \
# color cut
# D     Fair            53883   3.40    VVS2   71.6   73.0  16386   9.42   9.34
#       Good            53937   2.04    VVS2   67.0   66.0  18468   8.15   8.11
#       Ideal           53940   2.75    VVS2   64.5   62.0  18693   9.04   8.98
#       Premium         53935   2.57    VVS2   63.0   62.0  18575   8.99   8.94
#       Very Good       53938   2.58    VVS2   64.7   64.0  18542   9.08   9.01
# E     Fair            53728   2.04    VVS2   79.0   73.0  15584   8.16   8.04
#       Good            53891   3.00    VVS2   65.9   65.0  18236   9.08   8.96
#       Ideal           53927   2.28    VVS2   65.5   62.0  18729   8.52  31.80
#       Premium         53931   3.05    VVS2   63.0   62.0  18477   9.26   9.25
#       Very Good       53934   2.51    VVS2   64.5   65.0  18731   8.65   8.60
# F     Fair            53758   2.58    VVS2   71.0   95.0  17995   8.58   8.51
# ...

# %%
df.groupby(['price','cut']).aggregate('min')
# Out:
#                  Unnamed: 0  carat color clarity  depth  table     x     y  \
# price cut
# 326   Ideal               1   0.23     E     SI2   61.5   55.0  3.95  3.98
#       Premium             2   0.21     E     SI1   59.8   61.0  3.89  3.84
# 327   Good                3   0.23     E     VS1   56.9   65.0  4.05  4.07
# 334   Premium             4   0.29     I     VS2   62.4   58.0  4.20  4.23
# 335   Good                5   0.31     J     SI2   63.3   58.0  4.34  4.35
# ...                     ...    ...   ...     ...    ...    ...   ...   ...
# 18803 Very Good       27746   2.00     H     SI1   62.8   57.0  7.95  8.00
# 18804 Ideal           27747   2.07     G     SI2   62.5   55.0  8.20  8.13
# 18806 Ideal           27748   1.51     G      IF   61.7   55.0  7.37  7.41
# 18818 Very Good       27749   2.00     G     SI1   63.5   56.0  7.90  7.97
# 18823 Premium         27750   2.29     I     VS2   60.8   60.0  8.50  8.47
#
#                     z
# price cut
# ...

# %%
data = {
    'StudentID': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Math': [85, 78, 92, 88, 76],
    'Science': [90, 85, 88, 95, 80],
    'English': [82, 79, 94, 86, 88]
}

datax = pd.DataFrame(data)
datax
# Out:
#    StudentID     Name  Math  Science  English
# 0          1    Alice    85       90       82
# 1          2      Bob    78       85       79
# 2          3  Charlie    92       88       94
# 3          4    David    88       95       86
# 4          5      Eva    76       80       88

# %%
datax.agg(['sum','min','max'])
# Out:
#      StudentID                     Name  Math  Science  English
# sum         15  AliceBobCharlieDavidEva   419      438      429
# min          1                    Alice    76       80       79
# max          5                      Eva    92       95       94

# %%
datax.describe()
# Out:
#        StudentID       Math   Science    English
# count   5.000000   5.000000   5.00000   5.000000
# mean    3.000000  83.800000  87.60000  85.800000
# std     1.581139   6.723095   5.59464   5.761944
# min     1.000000  76.000000  80.00000  79.000000
# 25%     2.000000  78.000000  85.00000  82.000000
# 50%     3.000000  85.000000  88.00000  86.000000
# 75%     4.000000  88.000000  90.00000  88.000000
# max     5.000000  92.000000  95.00000  94.000000

# %%
datax.mean(numeric_only = True)
# Out:
# StudentID     3.0
# Math         83.8
# Science      87.6
# English      85.8
# dtype: float64

# %%
datax.sum(numeric_only = True)
# Out:
# StudentID     15
# Math         419
# Science      438
# English      429
# dtype: int64

# %%
datax.count(numeric_only = True)
# Out:
# StudentID    5
# Math         5
# Science      5
# English      5
# dtype: int64

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from list
df = pd.DataFrame(dict)

df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
test_df = df.copy()
test_df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
test_df.fillna(df.mean())
# Out:
#    First Score  Second Score  Third Score
# 0        100.0     30.000000    72.666667
# 1         90.0     45.000000    40.000000
# 2         95.0     56.000000    80.000000
# 3         95.0     43.666667    98.000000

# %%
test_df = df.copy()
test_df.fillna(method = "pad")
# Out:
# C:\Users\latai\AppData\Local\Temp\ipykernel_21356\3554201852.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test_df.fillna(method = "pad")
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
dict ={'A':[12, 4, 5, None, 1], 
                   'B':[None, 2, 54, 3, None], 
                  'C':[20, 16, None, 3, 8], 
                  'D':[14, 3, None, None, 6]}
df = pd.DataFrame(dict)
df
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
df.interpolate(method = "linear", limit_direction = "forward")
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %%
df.isnull().sum()
# Out:
# A    1
# B    2
# C    1
# D    2
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# dtype: int64

# %%
dict = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[60, 67, 68, 65]}

# creating a dataframe from dictionary  
df = pd.DataFrame(dict)

# %%
df.dropna(how = "all")
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 1          NaN           NaN          NaN            67
# 2          NaN          45.0         80.0            68
# 3         95.0          56.0         98.0            65

# %%
df.dropna(axis = 1)
# Out:
#    Fourth Score
# 0            60
# 1            67
# 2            68
# 3            65
