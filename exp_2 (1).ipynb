# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\latai\Downloads\nba - nba.csv")

# %%
data = pd.DataFrame(df)
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.head(10)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# 5   Amir Johnson  Boston Celtics      90       PF   29    6-9     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22    6-2     190
# 9   Marcus Smart  Boston Celtics      36       PG   22    6-4     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
# data.tail()

# %%
data.tail(10)
# Out:
#                Name       Team  Number Position  Age Height  Weight   College  \
# 447     Rudy Gobert  Utah Jazz      27        C   23    7-1     245       NaN
# 448  Gordon Hayward  Utah Jazz      20       SF   26    6-8     226    Butler
# 449     Rodney Hood  Utah Jazz       5       SG   23    6-8     206      Duke
# 450      Joe Ingles  Utah Jazz       2       SF   28    6-8     226       NaN
# 451   Chris Johnson  Utah Jazz      23       SF   26    6-6     206    Dayton
# 452      Trey Lyles  Utah Jazz      41       PF   20   6-10     234  Kentucky
# 453    Shelvin Mack  Utah Jazz       8       PG   26    6-3     203    Butler
# 454       Raul Neto  Utah Jazz      25       PG   24    6-1     179       NaN
# 455    Tibor Pleiss  Utah Jazz      21        C   26    7-3     256       NaN
# 456     Jeff Withey  Utah Jazz      24        C   26    7-0     231    Kansas
#
#          Salary
# 447   1175880.0
# 448  15409570.0
# 449   1348440.0
# 450   2050000.0
# 451    981348.0
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.loc[0]
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary           7730337.0
# Name: 0, dtype: object

# %%
data.loc[1:10]
# Out:
#                Name            Team  Number Position  Age Height  Weight  \
# 1       Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2      John Holland  Boston Celtics      30       SG   27    6-5     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# 5      Amir Johnson  Boston Celtics      90       PF   29    6-9     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8      Terry Rozier  Boston Celtics      12       PG   22    6-2     190
# 9      Marcus Smart  Boston Celtics      36       PG   22    6-4     220
# 10  Jared Sullinger  Boston Celtics       7        C   24    6-9     260
#
#               College      Salary
# 1           Marquette   6796117.0
# 2   Boston University         NaN
# 3       Georgia State   1148640.0
# ...

# %%
data.loc[20:30, ['Name','Team']]
# Out:
#                 Name             Team
# 20    Sergey Karasev    Brooklyn Nets
# 21   Sean Kilpatrick    Brooklyn Nets
# 22      Shane Larkin    Brooklyn Nets
# 23       Brook Lopez    Brooklyn Nets
# 24  Chris McCullough    Brooklyn Nets
# 25       Willie Reed    Brooklyn Nets
# 26   Thomas Robinson    Brooklyn Nets
# 27        Henry Sims    Brooklyn Nets
# 28      Donald Sloan    Brooklyn Nets
# 29    Thaddeus Young    Brooklyn Nets
# 30     Arron Afflalo  New York Knicks

# %%
data.iloc[100,3] #row,column
# Out:
# 'PG'

# %%
data.loc[100]
# Out:
# Name                  Chris Paul
# Team        Los Angeles Clippers
# Number                         3
# Position                      PG
# Age                           31
# Height                       6-0
# Weight                       175
# College              Wake Forest
# Salary                21468695.0
# Name: 100, dtype: object

# %%
data.iloc[3:10]
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# 5   Amir Johnson  Boston Celtics      90       PF   29    6-9     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22    6-2     190
# 9   Marcus Smart  Boston Celtics      36       PG   22    6-4     220
#
#           College      Salary
# 3   Georgia State   1148640.0
# 4             NaN   5000000.0
# 5             NaN  12000000.0
# 6             LSU   1170960.0
# 7         Gonzaga   2165160.0
# 8      Louisville   1824360.0
# 9  Oklahoma State   3431040.0

# %%
data.iloc[3:10:2,1:7:2] #row[start:stop:skip], column[start:stop:skip]
# Out:
#              Team Position Height
# 3  Boston Celtics       SG    6-5
# 5  Boston Celtics       PF    6-9
# 7  Boston Celtics        C    7-0
# 9  Boston Celtics       PG    6-4

# %%
data.iloc[3:10:2,[1,3,5]] #row[start:stop:skip], column[start:stop:skip]
# Out:
#              Team Position Height
# 3  Boston Celtics       SG    6-5
# 5  Boston Celtics       PF    6-9
# 7  Boston Celtics        C    7-0
# 9  Boston Celtics       PG    6-4

# %%
data1 = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'Name': ['John Doe', 'Jane Smith', 'Bob Johnson', 'Alice Brown', 'Mike Davis'],
    'Department': ['Engineering', 'Marketing', 'Sales', 'Engineering', 'Sales'],
    'Salary': [70000, 60000, 45000, 80000, 50000]
}
data2 = {
    'DepartmentID': [1, 2, 3, 4],
    'Department': ['Engineering', 'Marketing', 'Sales', 'HR'],
    'Manager': ['Tom Hanks', 'Sally Field', 'Denzel Washington', 'Meryl Streep']
}
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
print(data1)
print(data2)
# Out:
#    EmployeeID         Name   Department  Salary
# 0         101     John Doe  Engineering   70000
# 1         102   Jane Smith    Marketing   60000
# 2         103  Bob Johnson        Sales   45000
# 3         104  Alice Brown  Engineering   80000
# 4         105   Mike Davis        Sales   50000
#    DepartmentID   Department            Manager
# 0             1  Engineering          Tom Hanks
# 1             2    Marketing        Sally Field
# 2             3        Sales  Denzel Washington
# 3             4           HR       Meryl Streep

# %%
print(data1.sort_values(by = ['Salary']))
print(data1.sort_values(by = ['Name']))
# Out:
#    EmployeeID         Name   Department  Salary
# 2         103  Bob Johnson        Sales   45000
# 4         105   Mike Davis        Sales   50000
# 1         102   Jane Smith    Marketing   60000
# 0         101     John Doe  Engineering   70000
# 3         104  Alice Brown  Engineering   80000
#    EmployeeID         Name   Department  Salary
# 3         104  Alice Brown  Engineering   80000
# 2         103  Bob Johnson        Sales   45000
# 1         102   Jane Smith    Marketing   60000
# 0         101     John Doe  Engineering   70000
# 4         105   Mike Davis        Sales   50000

# %%
# ?pd.merge
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_on: 'IndexLabel | AnyArrayLike | None' = None,
#     right_on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
print(data1)
print(data2)
df = pd.merge(data1, data2, on = 'Department')
df
# Out:
#    EmployeeID         Name   Department  Salary
# 0         101     John Doe  Engineering   70000
# 1         102   Jane Smith    Marketing   60000
# 2         103  Bob Johnson        Sales   45000
# 3         104  Alice Brown  Engineering   80000
# 4         105   Mike Davis        Sales   50000
#    DepartmentID   Department            Manager
# 0             1  Engineering          Tom Hanks
# 1             2    Marketing        Sally Field
# 2             3        Sales  Denzel Washington
# 3             4           HR       Meryl Streep
#    EmployeeID         Name   Department  Salary  DepartmentID  \
# 0         101     John Doe  Engineering   70000             1
# 1         102   Jane Smith    Marketing   60000             2
# 2         103  Bob Johnson        Sales   45000             3
# 3         104  Alice Brown  Engineering   80000             1
# 4         105   Mike Davis        Sales   50000             3
#
#              Manager
# 0          Tom Hanks
# ...

# %%
data1 = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'DepartmentID': [1, 2, 3, 1, 3],
    'Name': ['John Doe', 'Jane Smith', 'Bob Johnson', 'Alice Brown', 'Mike Davis'],
    'Salary': [70000, 60000, 45000, 80000, 50000]
}
data2 = {
    'EmployeeID': [101, 102, 103, 106],
    'DepartmentID': [1, 2, 3, 4],
    'Project': ['Alpha', 'Beta', 'Gamma', 'Delta'],
    'HoursWorked': [35, 40, 25, 30]
}
dataa = pd.DataFrame(data1)
datab = pd.DataFrame(data2)

# %%
print(dataa)
print(datab)
# Out:
#    EmployeeID  DepartmentID         Name  Salary
# 0         101             1     John Doe   70000
# 1         102             2   Jane Smith   60000
# 2         103             3  Bob Johnson   45000
# 3         104             1  Alice Brown   80000
# 4         105             3   Mike Davis   50000
#    EmployeeID  DepartmentID Project  HoursWorked
# 0         101             1   Alpha           35
# 1         102             2    Beta           40
# 2         103             3   Gamma           25
# 3         106             4   Delta           30

# %%
data = pd.merge(dataa, datab, on = 'EmployeeID', how = 'left')
data
# Out:
#    EmployeeID  DepartmentID_x         Name  Salary  DepartmentID_y Project  \
# 0         101               1     John Doe   70000             1.0   Alpha
# 1         102               2   Jane Smith   60000             2.0    Beta
# 2         103               3  Bob Johnson   45000             3.0   Gamma
# 3         104               1  Alice Brown   80000             NaN     NaN
# 4         105               3   Mike Davis   50000             NaN     NaN
#
#    HoursWorked
# 0         35.0
# 1         40.0
# 2         25.0
# 3          NaN
# 4          NaN

# %%
datax = pd.merge(dataa, datab, on = 'EmployeeID', how = 'right')
datax
# Out:
#    EmployeeID  DepartmentID_x         Name   Salary  DepartmentID_y Project  \
# 0         101             1.0     John Doe  70000.0               1   Alpha
# 1         102             2.0   Jane Smith  60000.0               2    Beta
# 2         103             3.0  Bob Johnson  45000.0               3   Gamma
# 3         106             NaN          NaN      NaN               4   Delta
#
#    HoursWorked
# 0           35
# 1           40
# 2           25
# 3           30

# %%
datay = pd.merge(dataa, datab, on = 'EmployeeID', how = 'inner')
datay
# Out:
#    EmployeeID  DepartmentID_x         Name  Salary  DepartmentID_y Project  \
# 0         101               1     John Doe   70000               1   Alpha
# 1         102               2   Jane Smith   60000               2    Beta
# 2         103               3  Bob Johnson   45000               3   Gamma
#
#    HoursWorked
# 0           35
# 1           40
# 2           25

# %%
dataz = pd.merge(dataa, datab, on = 'EmployeeID', how = 'outer')
dataz
# Out:
#    EmployeeID  DepartmentID_x         Name   Salary  DepartmentID_y Project  \
# 0         101             1.0     John Doe  70000.0             1.0   Alpha
# 1         102             2.0   Jane Smith  60000.0             2.0    Beta
# 2         103             3.0  Bob Johnson  45000.0             3.0   Gamma
# 3         104             1.0  Alice Brown  80000.0             NaN     NaN
# 4         105             3.0   Mike Davis  50000.0             NaN     NaN
# 5         106             NaN          NaN      NaN             4.0   Delta
#
#    HoursWorked
# 0         35.0
# 1         40.0
# 2         25.0
# 3          NaN
# 4          NaN
# 5         30.0

# %%
data3 = data1 = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'DepartmentID': [1, 2, 3, 1, 3],
    'Name': ['Sam Wilson', 'Emily Clark', 'Michael Lee', 'Sarah Connor', 'David Harris'],
    'Salary': [70000, 60000, 45000, 80000, 50000]
}

datac = pd.DataFrame(data3)

# %%
pd.concat([dataa, datac])
# Out:
#    EmployeeID  DepartmentID          Name  Salary
# 0         101             1      John Doe   70000
# 1         102             2    Jane Smith   60000
# 2         103             3   Bob Johnson   45000
# 3         104             1   Alice Brown   80000
# 4         105             3    Mike Davis   50000
# 0         101             1    Sam Wilson   70000
# 1         102             2   Emily Clark   60000
# 2         103             3   Michael Lee   45000
# 3         104             1  Sarah Connor   80000
# 4         105             3  David Harris   50000

# %%
# ?pd.concat
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Docstring:
# Concatenate pandas objects along a particular axis.
#
# Allows optional set logic along the other axes.
#
# Can also add a layer of hierarchical indexing on the concatenation axis,
# which may be useful if the labels are the same (or overlapping) on
# the passed axis number.
#
# Parameters
# ----------
# objs : a sequence or mapping of Series or DataFrame objects
#     If a mapping is passed, the sorted keys will be used as the `keys`
#     argument, unless it is passed, in which case the values will be
# ...

# %%
res = pd.concat([dataa,datab], axis = 1, join = 'outer')
res
# Out:
#    EmployeeID  DepartmentID         Name  Salary  EmployeeID  DepartmentID  \
# 0         101             1     John Doe   70000       101.0           1.0
# 1         102             2   Jane Smith   60000       102.0           2.0
# 2         103             3  Bob Johnson   45000       103.0           3.0
# 3         104             1  Alice Brown   80000       106.0           4.0
# 4         105             3   Mike Davis   50000         NaN           NaN
#
#   Project  HoursWorked
# 0   Alpha         35.0
# 1    Beta         40.0
# 2   Gamma         25.0
# 3   Delta         30.0
# 4     NaN          NaN

# %%
res = pd.concat([dataa,datab], axis = 1, join = 'inner')
res
# Out:
#    EmployeeID  DepartmentID         Name  Salary  EmployeeID  DepartmentID  \
# 0         101             1     John Doe   70000         101             1
# 1         102             2   Jane Smith   60000         102             2
# 2         103             3  Bob Johnson   45000         103             3
# 3         104             1  Alice Brown   80000         106             4
#
#   Project  HoursWorked
# 0   Alpha           35
# 1    Beta           40
# 2   Gamma           25
# 3   Delta           30
